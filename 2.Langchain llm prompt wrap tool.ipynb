# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.agents import Tool

load_dotenv()
gemini_api_key=os.getenv('GOOGLE_API_KEY')

llm=ChatGoogleGenerativeAI(model='gemini-2.5-flash',temperature=0)

prompt=PromptTemplate.from_template("Answer clearly: {question}")

qa_chain=LLMChain(llm=llm,prompt=prompt)

qa_tool=Tool(
    name='Simple QA',
    func=qa_chain.run,
    description='A basic LLM that answers user queries clearly'
)

query=input("Enter your query: ")
response=qa_tool.invoke({'question':query})

print("User query: ",query)
print("\nLLM response: ",response)
# Out:
# Enter your query:  Top 5 companies for AI with chemical engineering in India
# User query:  Top 5 companies for AI with chemical engineering in India
#
# LLM response:  The intersection of AI and Chemical Engineering in India is a rapidly growing field, driven by the need for process optimization, predictive maintenance, new material discovery, and sustainable solutions in industries like petrochemicals, pharmaceuticals, and manufacturing.
#
# Here are 5 top companies in India where AI and Chemical Engineering expertise are significantly leveraged:
#
# 1.  **Reliance Industries Limited (RIL):**
#     *   **Why:** As India's largest conglomerate with massive operations in petrochemicals, refining, and new energy (hydrogen, advanced materials), RIL is a leader in digital transformation. They extensively use AI for process optimization in their refineries and chemical plants, predictive maintenance of complex machinery, supply chain optimization, and even in the development of new materials and sustainable processes. Chemical engineers are crucial for understanding the underlying processes that AI models optimize.
#
# 2.  **Tata Consultancy Services (TCS):**
#     *   **Why:** While primarily an IT services giant, TCS provides AI and digital transformation solutions to a vast array of global clients, including those in the chemical, oil & gas, and pharmaceutical sectors. They employ chemical engineers as domain experts to design, develop, and implement AI/ML solutions for process simulation, predictive analytics, smart manufacturing, and R&D for their industrial clients.
#
# 3.  **Larsen & Toubro (L&T):**
#     *   **Why:** L&T is a major EPC (Engineering, Procurement, and Construction) player for chemical plants, refineries, and other process industries. Their "L&T-NxT" initiative focuses on industrial digital transformation. They leverage AI for predictive maintenance of assets they build and operate, optimizing project execution, smart manufacturing solutions for clients, and improving operational efficiency in chemical and process industries. Chemical engineers are integral to understanding the plant operations and design.
#
# 4.  **Indian Oil Corporation Limited (IOCL) / Other Major Oil & Gas PSUs (e.g., BPCL, HPCL, ONGC):**
#     *   **Why:** These public sector undertakings are at the heart of India's energy sector, with extensive refining and marketing operations. They are increasingly adopting AI for refinery optimization (yield maximization, energy efficiency), predictive maintenance of pipelines and equipment, supply chain logistics, and even in exploration and production (for ONGC). Chemical engineers are fundamental to their core operations, and their expertise is vital for implementing and interpreting AI solutions in these complex chemical processes.
#
# 5.  **Dr. Reddy's Laboratories (or other major Pharmaceutical Companies like Cipla, Sun Pharma):**
#     *   **Why:** The pharmaceutical industry is inherently a chemical industry. Companies like Dr. Reddy's are investing heavily in AI for drug discovery, process optimization in manufacturing (e.g., optimizing reaction conditions, yield improvement), quality control, and supply chain management. Chemical engineers with a strong understanding of reaction kinetics, mass transfer, and process design are essential to integrate AI effectively into pharmaceutical R&D and production.
#
# These companies represent a mix of end-users of chemical engineering processes and solution providers, all actively integrating AI to drive efficiency, innovation, and sustainability.
