# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# %%
load_dotenv()
gemini_api_key=os.getenv('GOOGLE_API_KEY')

# %%
llm=ChatGoogleGenerativeAI(model='gemini-2.5-flash',temperature=0)

# %%
prompt=PromptTemplate.from_template("Answer clearly: {question}")

# %%
qa_chain=LLMChain(llm=llm,prompt=prompt)

# %%
query=input("Enter your query: ")
response=qa_chain.invoke({'question':query})
# Out:
# Enter your query:  Top 5 opportunities in AI

# %%
response
# Out:
# {'question': 'Top 5 opportunities in AI',
#  'text': "Here are the top 5 opportunities in AI, clearly defined:\n\n1.  **Hyper-Automation & Efficiency:** AI is revolutionizing industries by automating repetitive tasks, optimizing complex processes (supply chains, manufacturing, logistics), and enhancing operational efficiency across the board. This frees up human capital for more creative and strategic work, while significantly reducing costs and errors.\n\n2.  **Advanced Data Analytics & Predictive Insights:** AI's ability to process vast amounts of data, identify patterns, and make highly accurate predictions is invaluable. This opportunity spans fraud detection, personalized medicine, financial market forecasting, preventative maintenance, and targeted marketing, enabling smarter, data-driven decision-making.\n\n3.  **Generative AI & New Product/Service Creation:** The rise of generative AI (like large language models and image generators) is creating entirely new possibilities. This includes automated content creation (text, images, code, music), rapid prototyping, synthetic data generation for training other AIs, and the development of highly personalized and adaptive digital experiences and products.\n\n4.  **Hyper-Personalization & Enhanced Customer Experience:** AI allows businesses to understand and cater to individual customer needs at an unprecedented scale. This translates to highly personalized recommendations, adaptive learning platforms, intelligent chatbots for instant support, tailored marketing campaigns, and user interfaces that adapt to individual preferences, leading to increased satisfaction and loyalty.\n\n5.  **Solving Grand Challenges (Healthcare, Science, Sustainability):** AI is a powerful tool for tackling some of humanity's most complex problems. This includes accelerating drug discovery and development, improving diagnostic accuracy in healthcare, modeling climate change and developing sustainable solutions, optimizing energy grids, and advancing scientific research across various fields."}

# %%
print("User query: ",query)
print("\nLLM response: ",response['text'])
# Out:
# User query:  Top 5 opportunities in AI
#
# LLM response:  Here are the top 5 opportunities in AI, clearly defined:
#
# 1.  **Hyper-Automation & Efficiency:** AI is revolutionizing industries by automating repetitive tasks, optimizing complex processes (supply chains, manufacturing, logistics), and enhancing operational efficiency across the board. This frees up human capital for more creative and strategic work, while significantly reducing costs and errors.
#
# 2.  **Advanced Data Analytics & Predictive Insights:** AI's ability to process vast amounts of data, identify patterns, and make highly accurate predictions is invaluable. This opportunity spans fraud detection, personalized medicine, financial market forecasting, preventative maintenance, and targeted marketing, enabling smarter, data-driven decision-making.
#
# 3.  **Generative AI & New Product/Service Creation:** The rise of generative AI (like large language models and image generators) is creating entirely new possibilities. This includes automated content creation (text, images, code, music), rapid prototyping, synthetic data generation for training other AIs, and the development of highly personalized and adaptive digital experiences and products.
#
# 4.  **Hyper-Personalization & Enhanced Customer Experience:** AI allows businesses to understand and cater to individual customer needs at an unprecedented scale. This translates to highly personalized recommendations, adaptive learning platforms, intelligent chatbots for instant support, tailored marketing campaigns, and user interfaces that adapt to individual preferences, leading to increased satisfaction and loyalty.
#
# 5.  **Solving Grand Challenges (Healthcare, Science, Sustainability):** AI is a powerful tool for tackling some of humanity's most complex problems. This includes accelerating drug discovery and development, improving diagnostic accuracy in healthcare, modeling climate change and developing sustainable solutions, optimizing energy grids, and advancing scientific research across various fields.
